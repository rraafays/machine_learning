# %% [markdown]
# # Pandas: Series and DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Series

# %%
#Creating Series
lis = [np.random.randint(0,100) for x in range(0,6) ]#List comprehension
lis
# Out:
# [82, 67, 68, 81, 57, 63]

# %%
#Pass the list to the Series constructor
pd.Series(lis)
# Out:
# 0    82
# 1    67
# 2    68
# 3    81
# 4    57
# 5    63
# dtype: int64

# %%
#Creating Series from Numpy Arrays

lis = np.array(lis)
print("Array:",lis)
print("Series:\n", pd.Series(lis))
# Out:
# Array: [82 67 68 81 57 63]
# Series:
#  0    82
# 1    67
# 2    68
# 3    81
# 4    57
# 5    63
# dtype: int64

# %%
label = ['James','John','Jane','Maria','Sam','Jean']

# %%
s1 = pd.Series(lis,label, name = "Maths")

# %%
print(s1)
# Out:
# James    82
# John     67
# Jane     68
# Maria    81
# Sam      57
# Jean     63
# Name: Maths, dtype: int64

# %%
#Creating Series from Dictionaries
marks =  {'James':90,'John':87,'Jane':76,'Maria':90,'Sam':94,'Jean':76}

# %%
marks = pd.Series(marks)
marks
# Out:
# James    90
# John     87
# Jane     76
# Maria    90
# Sam      94
# Jean     76
# dtype: int64

# %% [markdown]
# # Retrieving Data from Series

# %% [markdown]
# Using index

# %%
marks['James']
# Out:
# 90

# %%
#s1[0]
#Deprecated
s1.iloc[0]
# Out:
# 82

# %% [markdown]
# #You can change or modify the data value of a Series

# %%
s1['Jane'] = 89

# %%
s1
# Out:
# James    82
# John     67
# Jane     89
# Maria    81
# Sam      57
# Jean     63
# Name: Maths, dtype: int64

# %%
s1[[0,1]]
# Out:
# /private/tmp/nix-shell-44647-0/ipykernel_45070/3009801939.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[[0,1]]
# James    82
# John     67
# Name: Maths, dtype: int64

# %%
#Using loc : To specifically state that we are using labelled index

# %%
s1.loc["James"]
# Out:
# 82

# %%
s1.loc[["James","Jane"]]
# Out:
# James    82
# Jane     89
# Name: Maths, dtype: int64

# %%
#Using iloc : To specifically state that we are using numeric index

# %%
s1.iloc[4]
# Out:
# 57

# %%
s1.iloc[[2,3]]
# Out:
# Jane     89
# Maria    81
# Name: Maths, dtype: int64

# %%
#Deleting Values from Series

# %%
s1.drop("Jane")#Note how jane's score still remains in the original Series. To  drop Janes, set the inplace parameter to true!
# Out:
# James    82
# John     67
# Maria    81
# Sam      57
# Jean     63
# Name: Maths, dtype: int64

# %%
s1
# Out:
# James    82
# John     67
# Jane     89
# Maria    81
# Sam      57
# Jean     63
# Name: Maths, dtype: int64

# %%
#Arithmetic operations on Pandas Series

# %%
s2 = s1 + 5
s2
# Out:
# James    87
# John     72
# Jane     94
# Maria    86
# Sam      62
# Jean     68
# Name: Maths, dtype: int64

# %%
#What is the average score?
s1.mean()
# Out:
# 73.16666666666667

# %%
s1[s1.idxmin()]
# Out:
# 57

# %%
s1.idxmax()
# Out:
# 'Jane'

# %%
np.max(s1)#Highest score
# Out:
# 89

# %%
s1["James"] + 20
# Out:
# 102

# %%
s1
# Out:
# James    82
# John     67
# Jane     89
# Maria    81
# Sam      57
# Jean     63
# Name: Maths, dtype: int64

# %%
#Lowest score?

# %% [markdown]
# # DataFrame
# Is a two dimensional object with rows and columns, can hold and process  data of mixed types!

# %%
#Let's create a DataFrame containing scores of 6 students in  6 subjects

# %%
score = [ np.random.randint(0,101) for x in range(0,36)]
print(score)
# Out:
# [100, 30, 10, 59, 98, 76, 26, 84, 86, 41, 13, 52, 34, 21, 88, 86, 61, 85, 81, 69, 50, 49, 39, 100, 18, 64, 57, 4, 82, 76, 49, 94, 16, 7, 82, 37]

# %%
scores = np.array(score)

# %%
scores
# Out:
# array([100,  30,  10,  59,  98,  76,  26,  84,  86,  41,  13,  52,  34,
#         21,  88,  86,  61,  85,  81,  69,  50,  49,  39, 100,  18,  64,
#         57,   4,  82,  76,  49,  94,  16,   7,  82,  37])

# %%
student_score = scores.reshape(6,6)

# %%
student_score
# Out:
# array([[100,  30,  10,  59,  98,  76],
#        [ 26,  84,  86,  41,  13,  52],
#        [ 34,  21,  88,  86,  61,  85],
#        [ 81,  69,  50,  49,  39, 100],
#        [ 18,  64,  57,   4,  82,  76],
#        [ 49,  94,  16,   7,  82,  37]])

# %%
students = ['James','John','Jane','Maria','Sam','Jean']
subjects = ['Maths','History','Physics','Chemistry','IT','Biology']

# %%
df = pd.DataFrame(data= student_score, index=students,columns=subjects)

# %%
df
# Out:
#        Maths  History  Physics  Chemistry  IT  Biology
# James    100       30       10         59  98       76
# John      26       84       86         41  13       52
# Jane      34       21       88         86  61       85
# Maria     81       69       50         49  39      100
# Sam       18       64       57          4  82       76
# Jean      49       94       16          7  82       37

# %%
#How to retrieve Maria's grade in Maths?

# %%
#How to retrieve students grades in Maths and Physics?

# %%
#Merging Dataframes
s1 = [90,87,78,95,76, 80]
s2 = [56,67,30,32,31, 90]

df1 = pd.DataFrame({"PE":s1}, index= students)
df2 = pd.DataFrame({"Music":s2}, index = students)

# %%
df1
# Out:
#        PE
# James  90
# John   87
# Jane   78
# Maria  95
# Sam    76
# Jean   80

# %%
df2
# Out:
#        Music
# James     56
# John      67
# Jane      30
# Maria     32
# Sam       31
# Jean      90

# %%
df3 = pd.merge(df1,df2,right_index=True, left_index=True)

# %%
df3
# Out:
#        PE  Music
# James  90     56
# John   87     67
# Jane   78     30
# Maria  95     32
# Sam    76     31
# Jean   80     90

# %%
#Exercise, merge df and df3.

# %%
df.plot(kind='bar')
display()
#plt.savefig('graph.png')

# %%
df.loc['James'].plot(kind = 'bar', y='Marks')
plt.xlabel("Subjects")
plt.ylabel("Grades")
display()

# %%
#Let's retrieve the index of our dataframe, this contains students' names

# %%
df.index#returns the index as an object
# Out:
# Index(['James', 'John', 'Jane', 'Maria', 'Sam', 'Jean'], dtype='object')

# %%
#Let's retrieve the columns of our dataframe, this contains the subjects!

# %%
df.columns#returns the columns as an object
# Out:
# Index(['Maths', 'History', 'Physics', 'Chemistry', 'IT', 'Biology'], dtype='object')

# %%
df.values#returns the data values as a 2-d array
# Out:
# array([[100,  30,  10,  59,  98,  76],
#        [ 26,  84,  86,  41,  13,  52],
#        [ 34,  21,  88,  86,  61,  85],
#        [ 81,  69,  50,  49,  39, 100],
#        [ 18,  64,  57,   4,  82,  76],
#        [ 49,  94,  16,   7,  82,  37]])

# %%
df.describe()#descriptive statistics of our dataframe
# Out:
#             Maths    History    Physics  Chemistry         IT     Biology
# count    6.000000   6.000000   6.000000   6.000000   6.000000    6.000000
# mean    51.333333  60.333333  51.166667  41.000000  62.500000   71.000000
# std     32.580158  29.152473  33.277119  31.426104  31.703312   22.821043
# min     18.000000  21.000000  10.000000   4.000000  13.000000   37.000000
# 25%     28.000000  38.500000  24.500000  15.500000  44.500000   58.000000
# 50%     41.500000  66.500000  53.500000  45.000000  71.500000   76.000000
# 75%     73.000000  80.250000  78.750000  56.500000  82.000000   82.750000
# max    100.000000  94.000000  88.000000  86.000000  98.000000  100.000000

# %% [markdown]
# # Retrieving Data from DataFrame

# %%
#let's retrieve all scores for Biology

x = df["Biology"]
print(type(x))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#for multiple columns
df[["Biology","Chemistry"]]
# Out:
#        Biology  Chemistry
# James       76         59
# John        52         41
# Jane        85         86
# Maria      100         49
# Sam         76          4
# Jean        37          7

# %%
#What did James score in Maths? Do not use the index in the first []!
df['Maths']['James']
# Out:
# 100

# %%
#Retrieving a row. What did John score in all subjects?

# %%
df.loc[["John"]]
# Out:
#       Maths  History  Physics  Chemistry  IT  Biology
# John     26       84       86         41  13       52

# %%
df.loc[["John"]]#
# Out:
#       Maths  History  Physics  Chemistry  IT  Biology
# John     26       84       86         41  13       52

# %% [markdown]
# # Adding Columns to DataFrame

# %%
#Adding new Columns. Let's add the scores of all students in Geography!
df["Geography"] = [56,78,86,34,45,70]

# %%
df
# Out:
#        Maths  History  Physics  Chemistry  IT  Biology  Geography
# James    100       30       10         59  98       76         56
# John      26       84       86         41  13       52         78
# Jane      34       21       88         86  61       85         86
# Maria     81       69       50         49  39      100         34
# Sam       18       64       57          4  82       76         45
# Jean      49       94       16          7  82       37         70

# %%
#Adding new rows. Let's add the scores for Patrick.
Patrick = {"Maths":78,"History":67,"Physics":90,"Chemistry":76,"IT":98,"Geography":78}

# %%
patrick_df = pd.DataFrame(Patrick, index=["Patrick"])

# %%
patrick_df
# Out:
#          Maths  History  Physics  Chemistry  IT  Geography
# Patrick     78       67       90         76  98         78

# %%
df_1 = df._append(patrick_df, ignore_index= False)
df_1
# Out:
#          Maths  History  Physics  Chemistry  IT  Biology  Geography
# James      100       30       10         59  98     76.0         56
# John        26       84       86         41  13     52.0         78
# Jane        34       21       88         86  61     85.0         86
# Maria       81       69       50         49  39    100.0         34
# Sam         18       64       57          4  82     76.0         45
# Jean        49       94       16          7  82     37.0         70
# Patrick     78       67       90         76  98      NaN         78

# %%
df_1.loc['Patrick','Biology'] = 89
df_1
# Out:
#          Maths  History  Physics  Chemistry  IT  Biology  Geography
# James      100       30       10         59  98     76.0         56
# John        26       84       86         41  13     52.0         78
# Jane        34       21       88         86  61     85.0         86
# Maria       81       69       50         49  39    100.0         34
# Sam         18       64       57          4  82     76.0         45
# Jean        49       94       16          7  82     37.0         70
# Patrick     78       67       90         76  98     89.0         78

# %%
#Inserting columns to specific location. Let's add scores for new subject(Arts) at column(0)

df.insert(0,"Arts",[90,67,88,98,67,85])

# %%
df
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Geography
# James    90    100       30       10         59  98       76         56
# John     67     26       84       86         41  13       52         78
# Jane     88     34       21       88         86  61       85         86
# Maria    98     81       69       50         49  39      100         34
# Sam      67     18       64       57          4  82       76         45
# Jean     85     49       94       16          7  82       37         70

# %% [markdown]
# # Deletion
# You can delete using pop and drop functions of DataFrame

# %%
# Deleting using pop and drop functions
#Pop deletes columns, drop deletes both columns and rows

# %%
df.pop("Geography")
# Out:
# James    56
# John     78
# Jane     86
# Maria    34
# Sam      45
# Jean     70
# Name: Geography, dtype: int64

# %%
df
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology
# James    90    100       30       10         59  98       76
# John     67     26       84       86         41  13       52
# Jane     88     34       21       88         86  61       85
# Maria    98     81       69       50         49  39      100
# Sam      67     18       64       57          4  82       76
# Jean     85     49       94       16          7  82       37

# %%
#Deleting columns using drop function, remember to set the axis to 1
dropped = df.drop(["Arts", "Biology"], axis=1)
dropped
# Out:
#        Maths  History  Physics  Chemistry  IT
# James    100       30       10         59  98
# John      26       84       86         41  13
# Jane      34       21       88         86  61
# Maria     81       69       50         49  39
# Sam       18       64       57          4  82
# Jean      49       94       16          7  82

# %%
#deleting rows using drop function...remember to set the axis to 0.
dropped = df.drop(["James", "John"], axis=0)
dropped
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology
# Jane     88     34       21       88         86  61       85
# Maria    98     81       69       50         49  39      100
# Sam      67     18       64       57          4  82       76
# Jean     85     49       94       16          7  82       37

# %%
#Changing row/columns label using rename function
df.rename(columns={"IT":"Computing"})
# Out:
#        Arts  Maths  History  Physics  Chemistry  Computing  Biology
# James    90    100       30       10         59         98       76
# John     67     26       84       86         41         13       52
# Jane     88     34       21       88         86         61       85
# Maria    98     81       69       50         49         39      100
# Sam      67     18       64       57          4         82       76
# Jean     85     49       94       16          7         82       37

# %%
#Changing row/columns label using rename function
df.rename(index={"Sam":"Samuel"})
# Out:
#         Arts  Maths  History  Physics  Chemistry  IT  Biology
# James     90    100       30       10         59  98       76
# John      67     26       84       86         41  13       52
# Jane      88     34       21       88         86  61       85
# Maria     98     81       69       50         49  39      100
# Samuel    67     18       64       57          4  82       76
# Jean      85     49       94       16          7  82       37

# %% [markdown]
# # Cleaning Data
# How to deal with missing values.

# %%
import math
NaN = float('nan')
df["Agriculture"] = [56,78,NaN,34,NaN,70]

#df["Maths"]["Jean"]=NaN
#df["Biology"]["Jean"]=NaN

df
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85          NaN
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76          NaN
# Jean     85     49       94       16          7  82       37         70.0

# %%
df_null = df.isnull()
df_null
# Out:
#         Arts  Maths  History  Physics  Chemistry     IT  Biology  Agriculture
# James  False  False    False    False      False  False    False        False
# John   False  False    False    False      False  False    False        False
# Jane   False  False    False    False      False  False    False         True
# Maria  False  False    False    False      False  False    False        False
# Sam    False  False    False    False      False  False    False         True
# Jean   False  False    False    False      False  False    False        False

# %%
df.isnull().sum()
# Out:
# Arts           0
# Maths          0
# History        0
# Physics        0
# Chemistry      0
# IT             0
# Biology        0
# Agriculture    2
# dtype: int64

# %%
df_null["Maths"]
# Out:
# James    False
# John     False
# Jane     False
# Maria    False
# Sam      False
# Jean     False
# Name: Maths, dtype: bool

# %%
df_null.sum()#number of NaN in the DF
# Out:
# Arts           0
# Maths          0
# History        0
# Physics        0
# Chemistry      0
# IT             0
# Biology        0
# Agriculture    2
# dtype: int64

# %%
df.count()#counts the number of non null values
# Out:
# Arts           6
# Maths          6
# History        6
# Physics        6
# Chemistry      6
# IT             6
# Biology        6
# Agriculture    4
# dtype: int64

# %%
#Dealing with NaN values: This can be achieved by using dropna function  or fillna function.

# %%
df.dropna(axis=0)#drops the rows with the missing values
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Maria    98     81       69       50         49  39      100         34.0
# Jean     85     49       94       16          7  82       37         70.0

# %%
df.dropna(axis=1)#drops the columns with the missing values
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology
# James    90    100       30       10         59  98       76
# John     67     26       84       86         41  13       52
# Jane     88     34       21       88         86  61       85
# Maria    98     81       69       50         49  39      100
# Sam      67     18       64       57          4  82       76
# Jean     85     49       94       16          7  82       37

# %%
#Filling missing values with 0
df.fillna(0)
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85          0.0
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76          0.0
# Jean     85     49       94       16          7  82       37         70.0

# %%
# forward fill:replaces missing values from previous item in the column or row

df.ffill()
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85         78.0
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76         34.0
# Jean     85     49       94       16          7  82       37         70.0

# %%
df
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85          NaN
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76          NaN
# Jean     85     49       94       16          7  82       37         70.0

# %%
#propagate non-null values forward
df.ffill()
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85         78.0
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76         34.0
# Jean     85     49       94       16          7  82       37         70.0

# %%
#propagate non-null values backward
df.bfill()#Backward fill
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85         34.0
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76         70.0
# Jean     85     49       94       16          7  82       37         70.0

# %%
df
# Out:
#        Arts  Maths  History  Physics  Chemistry  IT  Biology  Agriculture
# James    90    100       30       10         59  98       76         56.0
# John     67     26       84       86         41  13       52         78.0
# Jane     88     34       21       88         86  61       85          NaN
# Maria    98     81       69       50         49  39      100         34.0
# Sam      67     18       64       57          4  82       76          NaN
# Jean     85     49       94       16          7  82       37         70.0

# %%
#Filling missing values using interpolation functions
df.interpolate(method='linear',axis=1)
# Out:
#        Arts  Maths  History  Physics  Chemistry    IT  Biology  Agriculture
# James  90.0  100.0     30.0     10.0       59.0  98.0     76.0         56.0
# John   67.0   26.0     84.0     86.0       41.0  13.0     52.0         78.0
# Jane   88.0   34.0     21.0     88.0       86.0  61.0     85.0         85.0
# Maria  98.0   81.0     69.0     50.0       49.0  39.0    100.0         34.0
# Sam    67.0   18.0     64.0     57.0        4.0  82.0     76.0         76.0
# Jean   85.0   49.0     94.0     16.0        7.0  82.0     37.0         70.0

# %%
#Loading data into DataFrames. We can load data files into Pandas DataFrame.
#This is a real-world data containing labelled smartphone sensor data

# %%
#Link to User context recognition using smartphone sensors and classification models
#https://www.sciencedirect.com/science/article/pii/S1084804516300261
context = pd.read_csv("mobile_context.csv", index_col=0)

# %%
context.head(20)
# Out:
#                 time location  latitude  longitude  accuracy  altitude  \
# _id
# 1    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 2    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 3    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 4    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 5    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 6    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 7    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 8    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 9    20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 10   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 11   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 12   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 13   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 14   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 15   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 16   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 17   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 18   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 19   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
# 20   20120711_192342   Office   41.1795   -8.59533      45.0       0.0
#
#      bearing  speed  orientTimestamp  orX  ...  temperature  lightTimestamp  \
# _id                                        ...
# 1        0.0    0.0       1342031022  125  ...            0      1342031014
# 2        0.0    0.0       1342031022  126  ...            0      1342031014
# 3        0.0    0.0       1342031022  127  ...            0      1342031014
# 4        0.0    0.0       1342031022  127  ...            0      1342031014
# 5        0.0    0.0       1342031022  127  ...            0      1342031014
# 6        0.0    0.0       1342031022  127  ...            0      1342031014
# 7        0.0    0.0       1342031022  127  ...            0      1342031014
# 8        0.0    0.0       1342031022  127  ...            0      1342031014
# 9        0.0    0.0       1342031022  127  ...            0      1342031014
# 10       0.0    0.0       1342031022  127  ...            0      1342031014
# 11       0.0    0.0       1342031022  127  ...            0      1342031014
# 12       0.0    0.0       1342031022  127  ...            0      1342031014
# 13       0.0    0.0       1342031022  127  ...            0      1342031014
# 14       0.0    0.0       1342031022  127  ...            0      1342031014
# 15       0.0    0.0       1342031022  127  ...            0      1342031014
# 16       0.0    0.0       1342031022  127  ...            0      1342031014
# 17       0.0    0.0       1342031022  127  ...            0      1342031014
# 18       0.0    0.0       1342031022  127  ...            0      1342031014
# 19       0.0    0.0       1342031022  127  ...            0      1342031014
# 20       0.0    0.0       1342031022  127  ...            0      1342031014
#
#      illumination   lux  soundTimestamp  noiseLevel  soundLevel  withPeople  \
# _id
# 1          Normal  5000      1342031022      Normal       49.56         Yes
# 2          Normal  5000      1342031022      Normal       53.38         Yes
# 3          Normal  5000      1342031022      Normal       53.38         Yes
# 4          Normal  5000      1342031022      Normal       49.53         Yes
# 5          Normal  5000      1342031022      Normal       49.53         Yes
# 6          Normal  5000      1342031022      Normal       49.53         Yes
# 7          Normal  5000      1342031022      Normal       50.25         Yes
# 8          Normal  5000      1342031022      Normal       50.25         Yes
# 9          Normal  5000      1342031022      Normal       50.25         Yes
# 10         Normal  5000      1342031022      Normal       50.25         Yes
# 11         Normal  5000      1342031022      Normal       51.59         Yes
# 12         Normal  5000      1342031022      Normal       51.59         Yes
# 13         Normal  5000      1342031022      Normal       51.59         Yes
# 14         Normal  5000      1342031022      Normal       49.93         Yes
# 15         Normal  5000      1342031022      Normal       49.93         Yes
# 16         Normal  5000      1342031022      Normal       49.93         Yes
# 17         Normal  5000      1342031022      Normal       49.93         Yes
# 18         Normal  5000      1342031022      Normal       49.93         Yes
# 19         Normal  5000      1342031022      Normal       49.93         Yes
# 20         Normal  5000      1342031022      Normal       49.93         Yes
#
#      travelledOutside  activity
# _id
# 1                  No   Sitting
# 2                  No   Sitting
# 3                  No   Sitting
# 4                  No   Sitting
# 5                  No   Sitting
# 6                  No   Sitting
# 7                  No   Sitting
# 8                  No   Sitting
# 9                  No   Sitting
# 10                 No   Sitting
# 11                 No   Sitting
# 12                 No   Sitting
# 13                 No   Sitting
# 14                 No   Sitting
# 15                 No   Sitting
# 16                 No   Sitting
# 17                 No   Sitting
# 18                 No   Sitting
# 19                 No   Sitting
# 20                 No   Sitting
#
# [20 rows x 47 columns]

# %%
context.tail(10)
# Out:
#                   time location  latitude  longitude  accuracy  altitude  \
# _id
# 18591  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18592  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18593  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18594  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18595  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18596  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18597  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18598  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18599  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
# 18600  20120712_095757   Office   41.1797   -8.59488   85.3593   231.001
#
#        bearing    speed  orientTimestamp  orX  ...  temperature  \
# _id                                            ...
# 18591  241.407  1.50249       1342083477  127  ...            0
# 18592  241.407  1.50249       1342083477  128  ...            0
# 18593  241.407  1.50249       1342083477  128  ...            0
# 18594  241.407  1.50249       1342083477  128  ...            0
# 18595  241.407  1.50249       1342083477  128  ...            0
# 18596  241.407  1.50249       1342083477  128  ...            0
# 18597  241.407  1.50249       1342083477  128  ...            0
# 18598  241.407  1.50249       1342083477  128  ...            0
# 18599  241.407  1.50249       1342083477  128  ...            0
# 18600  241.407  1.50249       1342083477  128  ...            0
#
#        lightTimestamp  illumination   lux  soundTimestamp  noiseLevel  \
# _id
# 18591      1342083399        Normal  5000      1342083477      Normal
# 18592      1342083399        Normal  5000      1342083477      Normal
# 18593      1342083399        Normal  5000      1342083477      Normal
# 18594      1342083399        Normal  5000      1342083477      Normal
# 18595      1342083399        Normal  5000      1342083477      Normal
# 18596      1342083399        Normal  5000      1342083477      Normal
# 18597      1342083399        Normal  5000      1342083477      Normal
# 18598      1342083399        Normal  5000      1342083477      Normal
# 18599      1342083399        Normal  5000      1342083477      Normal
# 18600      1342083399        Normal  5000      1342083477      Normal
#
#        soundLevel  withPeople  travelledOutside  activity
# _id
# 18591       47.92         Yes                No   Sitting
# 18592       47.92         Yes                No   Sitting
# 18593       47.92         Yes                No   Sitting
# 18594       47.92         Yes                No   Sitting
# 18595       47.92         Yes                No   Sitting
# 18596       47.92         Yes                No   Sitting
# 18597       47.92         Yes                No   Sitting
# 18598       47.92         Yes                No   Sitting
# 18599       47.92         Yes                No   Sitting
# 18600       47.92         Yes                No   Sitting
#
# [10 rows x 47 columns]

# %%
context.isnull().any()
# Out:
# time                    True
# location               False
# latitude               False
# longitude              False
# accuracy               False
# altitude               False
# bearing                False
# speed                  False
# orientTimestamp        False
# orX                    False
# orY                    False
# orZ                    False
# rotationTimestamp      False
# rX                     False
# rY                     False
# rZ                     False
# acceTimestamp          False
# accX                   False
# accY                   False
# accZ                   False
# accele                 False
# linearAcceTimestamp    False
# laccX                  False
# laccY                  False
# laccZ                  False
# linear                 False
# gravityTimestamp       False
# gX                     False
# gY                     False
# gZ                     False
# magTimestamp           False
# mX                     False
# mY                     False
# mZ                     False
# proximityTimestamp     False
# proximity              False
# tempTimestamp          False
# temperature            False
# lightTimestamp         False
# illumination           False
# lux                    False
# soundTimestamp         False
# noiseLevel             False
# soundLevel             False
# withPeople             False
# travelledOutside       False
# activity               False
# dtype: bool

# %%
time =  context['time']

# %%
time.head(20)
# Out:
# _id
# 1     20120711_192342
# 2     20120711_192342
# 3     20120711_192342
# 4     20120711_192342
# 5     20120711_192342
# 6     20120711_192342
# 7     20120711_192342
# 8     20120711_192342
# 9     20120711_192342
# 10    20120711_192342
# 11    20120711_192342
# 12    20120711_192342
# 13    20120711_192342
# 14    20120711_192342
# 15    20120711_192342
# 16    20120711_192342
# 17    20120711_192342
# 18    20120711_192342
# 19    20120711_192342
# 20    20120711_192342
# Name: time, dtype: object

# %%
context.describe()
# Out:
#            latitude     longitude      accuracy      altitude       bearing  \
# count  18600.000000  18600.000000  18600.000000  18600.000000  18600.000000
# mean      40.381329     -8.428350     94.527439    161.084785    160.604640
# std        5.673240      1.184119    209.105693     84.982965    129.232448
# min        0.000000     -8.603790      0.000000      0.000000      0.000000
# 25%       41.175000     -8.596750     30.000000    163.000000      0.000000
# 50%       41.179100     -8.594880     30.000000    192.000000    214.409000
# 75%       41.179700     -8.590210     81.884200    217.000000    277.407000
# max       41.183200      0.000000   1168.000000    250.000000    359.943000
#
#               speed  orientTimestamp           orX           orY  \
# count  18600.000000     1.860000e+04  18600.000000  18600.000000
# mean       1.087794     1.316077e+09    173.359032      5.794839
# std        0.747194     1.848979e+08     83.037722      9.298455
# min        0.000000     0.000000e+00      0.000000    -55.000000
# 25%        0.000000     1.342033e+09    106.000000      1.000000
# 50%        1.446680     1.342036e+09    196.000000      6.000000
# 75%        1.522270     1.342083e+09    238.000000     12.000000
# max        2.675580     1.342083e+09    359.000000     43.000000
#
#                 orZ  ...            mY            mZ  proximityTimestamp  \
# count  18600.000000  ...  18600.000000  18600.000000        1.860000e+04
# mean       4.024194  ...     -7.906172    -32.648602        1.316077e+09
# std       16.587193  ...     17.939106     16.197006        1.848978e+08
# min      -28.000000  ...    -53.600000    -72.800000        0.000000e+00
# 25%       -1.000000  ...    -20.800000    -42.400000        1.342033e+09
# 50%        1.000000  ...     -5.200000    -38.000000        1.342036e+09
# 75%        3.000000  ...      5.200000    -24.800000        1.342083e+09
# max       88.000000  ...     31.600000     20.800000        1.342083e+09
#
#           proximity  tempTimestamp  temperature  lightTimestamp           lux  \
# count  18600.000000        18600.0      18600.0    1.860000e+04  18600.000000
# mean       4.876344            0.0          0.0    1.316077e+09   4574.988978
# std        0.776544            0.0          0.0    1.848978e+08   3618.845653
# min        0.000000            0.0          0.0    0.000000e+00      0.000000
# 25%        5.000000            0.0          0.0    1.342033e+09   1000.000000
# 50%        5.000000            0.0          0.0    1.342036e+09   5000.000000
# 75%        5.000000            0.0          0.0    1.342083e+09   5000.000000
# max        5.000000            0.0          0.0    1.342083e+09  10000.000000
#
#        soundTimestamp    soundLevel
# count    1.860000e+04  18600.000000
# mean     1.316077e+09     52.551238
# std      1.848979e+08      9.671707
# min      0.000000e+00      0.000000
# 25%      1.342033e+09     50.450000
# 50%      1.342036e+09     53.800000
# 75%      1.342083e+09     57.240000
# max      1.342083e+09     70.020000
#
# [8 rows x 40 columns]

# %%
context.columns
# Out:
# Index(['time', 'location', 'latitude', 'longitude', 'accuracy', 'altitude',
#        'bearing', 'speed', 'orientTimestamp', 'orX', 'orY', 'orZ',
#        'rotationTimestamp', 'rX', 'rY', 'rZ', 'acceTimestamp', 'accX', 'accY',
#        'accZ', 'accele', 'linearAcceTimestamp', 'laccX', 'laccY', 'laccZ',
#        'linear', 'gravityTimestamp', 'gX', 'gY', 'gZ', 'magTimestamp', 'mX',
#        'mY', 'mZ', 'proximityTimestamp', 'proximity', 'tempTimestamp',
#        'temperature', 'lightTimestamp', 'illumination', 'lux',
#        'soundTimestamp', 'noiseLevel', 'soundLevel', 'withPeople',
#        'travelledOutside', 'activity'],
#       dtype='object')

# %%
context["lux"].describe()
# Out:
# count    18600.000000
# mean      4574.988978
# std       3618.845653
# min          0.000000
# 25%       1000.000000
# 50%       5000.000000
# 75%       5000.000000
# max      10000.000000
# Name: lux, dtype: float64

# %%
#Retrieve specific columns into a new DataFrame?

# %% [markdown]
# #Let's load another data from CSV file

# %%
pop = pd.read_csv("state-population.csv")

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
population = pop.rename(columns={"state/region":"state"})#Changes the column label

# %%
population.head()
# Out:
#   state     ages  year  population
# 0    AL  under18  2012   1117489.0
# 1    AL    total  2012   4817528.0
# 2    AL  under18  2010   1130966.0
# 3    AL    total  2010   4785570.0
# 4    AL  under18  2011   1125763.0

# %%
# %matplotlib inline
population.groupby(['year'])['population'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
population.groupby(['state'])['population'].mean()
# Out:
# state
# AK     4.164389e+05
# AL     2.797862e+06
# AR     1.686640e+06
# AZ     3.337577e+06
# CA     2.170908e+07
# CO     2.727803e+06
# CT     2.128442e+06
# DC     3.496533e+05
# DE     4.979201e+05
# FL     1.008313e+07
# GA     5.285421e+06
# HI     7.781240e+05
# IA     1.831789e+06
# ID     8.576250e+05
# IL     7.757703e+06
# IN     3.838380e+06
# KS     1.703569e+06
# KY     2.536397e+06
# LA     2.811572e+06
# MA     3.891187e+06
# MD     3.357502e+06
# ME     7.906852e+05
# MI     6.157709e+06
# MN     3.108525e+06
# MO     3.522333e+06
# MS     1.794283e+06
# MT     5.716055e+05
# NC     5.140725e+06
# ND     4.066764e+05
# NE     1.087942e+06
# NH     7.675910e+05
# NJ     5.227053e+06
# NM     1.175271e+06
# NV     1.310279e+06
# NY     1.171282e+07
# OH     7.079279e+06
# OK     2.192022e+06
# OR     2.146920e+06
# PA     7.615765e+06
# PR     2.367490e+06
# RI     6.390411e+05
# SC     2.569703e+06
# SD     4.840280e+05
# TN     3.579156e+06
# TX     1.381758e+07
# USA    1.782390e+08
# UT     1.536009e+06
# VA     4.494164e+06
# VT     3.735618e+05
# WA     3.747736e+06
# WI     3.371227e+06
# WV     1.114171e+06
# WY     3.212865e+05
# Name: population, dtype: float64

# %%
population.groupby(['state','year'])['population'].mean()
# Out:
# state  year
# AK     1990    365396.0
#        1991    376186.5
#        1992    386807.0
#        1993    393312.0
#        1994    395373.5
#                  ...
# WY     2009    347405.5
#        2010    349786.5
#        2011    351368.0
#        2012    356576.0
#        2013    360168.5
# Name: population, Length: 1272, dtype: float64

# %%
# %%time
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
wine = pd.read_csv(url,sep=';')

#You can use the pd.to_csv() to persist the wine data to your local drive.
# Out:
# CPU times: user 18.4 ms, sys: 4.52 ms, total: 22.9 ms
# Wall time: 1.09 s

# %%
wine.head()#Displays the first 5 records of the wine DataFrame, you can change the number of records to be displayed.
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.info()#Displays the total number of entries, columns( with data types) and the memory usage of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.values#
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
#What is the average alcohol % per vol?

wine['alcohol'].mean()
# Out:
# 10.422983114446529

# %%
#Let's group the wine according to quality and visualize the grouping

wine.groupby("quality").plot()
# Out:
# quality
# 3    Axes(0.125,0.11;0.775x0.77)
# 4    Axes(0.125,0.11;0.775x0.77)
# 5    Axes(0.125,0.11;0.775x0.77)
# 6    Axes(0.125,0.11;0.775x0.77)
# 7    Axes(0.125,0.11;0.775x0.77)
# 8    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.plot(kind="scatter",x="quality",y="alcohol")
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
#Compute the wine quality and alcohol ratio

# %%
wine['qual_alc ratio'] = wine['quality']/wine['alcohol']

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  qual_alc ratio
# 0      9.4        5        0.531915
# 1      9.8        5        0.510204
# 2      9.8        5        0.510204
# 3      9.8        6        0.612245
# 4      9.4        5        0.531915

# %%
#Sort the wine in descending order of quality

# %%
wino= wine.sort_values(by='quality', ascending=False)

# %%
wino.head(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 495            10.7              0.35         0.53             2.6      0.070
# 1403            7.2              0.33         0.33             1.7      0.061
# 390             5.6              0.85         0.05             1.4      0.045
# 1061            9.1              0.40         0.50             1.8      0.071
# 1202            8.6              0.42         0.39             1.8      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 495                   5.0                  16.0  0.99720  3.15       0.65
# 1403                  3.0                  13.0  0.99600  3.23       1.10
# 390                  12.0                  88.0  0.99240  3.56       0.82
# 1061                  7.0                  16.0  0.99462  3.21       0.69
# 1202                  6.0                  12.0  0.99516  3.35       0.69
#
#       alcohol  quality  qual_alc ratio
# 495      11.0        8        0.727273
# 1403     10.0        8        0.800000
# 390      12.9        8        0.620155
# 1061     12.5        8        0.640000
# 1202     11.7        8        0.683761
